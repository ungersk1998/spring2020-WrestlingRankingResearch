# %%
import pandas as pd

import matplotlib.pyplot as plt

import random
import math

# %%
# Load in matches and wrestlers dataframes, label IDs
MATCHES = pd.read_csv('MATCHES.csv').rename(columns={'Unnamed: 0':'Match ID'})
WRESTLERS = pd.read_csv('WRESTLERS.csv').rename(columns={'Unnamed: 0':'Wrestler ID'})

# %%
MATCHES.shape # number of matches, recorded match variables
# Out:
# (20618, 21)

# %%
MATCHES.columns
# Out:
# Index(['Match ID', 'Weight Class', 'Victory Type (L)', 'Victory Type (S)',
#        'Winner Score', 'Loser Score', 'Winner First Name', 'Winner Last Name',
#        'Winner School (L)', 'Winner School (S)', 'Loser First Name',
#        'Loser Last Name', 'Loser School (L)', 'Loser School (S)',
#        'Unknown (Seed?)', 'Round', 'Event Name', 'Event ID',
#        'Event Order (1=newest)', 'Winner Full Name', 'Loser Full Name'],
#       dtype='object')

# %%
MATCHES
# Out:
#        Match ID  Weight Class Victory Type (L) Victory Type (S)  Winner Score  \
# 0             0           120             Fall             Fall           0.0
# 1             1           138   Technical Fall               TF          16.0
# 2             2           220             Fall             Fall           0.0
# 3             3           220         Decision              Dec           1.0
# 4             4           113             Fall             Fall           0.0
# ...         ...           ...              ...              ...           ...
# 20613     20613           182             Fall             Fall           0.0
# 20614     20614           195         Decision              Dec           4.0
# 20615     20615           195             Fall             Fall           0.0
# 20616     20616           220             Fall             Fall           0.0
# 20617     20617           285             Fall             Fall           0.0
#
# ...

# %%
WRESTLERS.shape # number of wrestlers, recorded wrestler variables
# Out:
# (3915, 10)

# %%
WRESTLERS.columns
# Out:
# Index(['Wrestler ID', 'First Name', 'Last Name', 'Full Name', 'School Name',
#        'School Code', 'Weight Class', 'Wins', 'Losses', 'Matches'],
#       dtype='object')

# %%
WRESTLERS
# Out:
#       Wrestler ID First Name   Last Name        Full Name  \
# 0               0      Blake   Colantino  Blake Colantino
# 1               1     Angelo        Lupo      Angelo Lupo
# 2               2       Jake      Elliot      Jake Elliot
# 3               3       John     Tietjen     John Tietjen
# 4               4       Will    Mendofik    Will Mendofik
# ...           ...        ...         ...              ...
# 3910         3910       Nate  Hollenbeck  Nate Hollenbeck
# 3911         3911      Aidan     Macleod    Aidan Macleod
# 3912         3912     Collin       Brule     Collin Brule
# 3913         3913      Ethan     Coleman    Ethan Coleman
# 3914         3914       Zack       Nacco       Zack Nacco
#
#                     School Name School Code  Weight Class  Wins  Losses  \
# 0                       Eden HS        EDHS           126    12       2
# 1     Half Hollow Hills HS-East        HHHE           132    12      18
# ...

# %%
# Copy infoscrape function from Wrestling Tables notebook

def infoscrape(fullname,df):
    '''infoscrape receives full name of wrestler and matches dataframe
    and collects wrestler info from dataset'''

    # Initialize values of interest
    weight_class = 0
    wins = 0
    losses = 0
    matches = 0
    school = ''
    school_code = ''
    first_name = ''
    last_name = ''
    
    # Find observations corresponding to wrestler name
    win_id = df['Winner Full Name'] == fullname
    loss_id = df['Loser Full Name'] == fullname
    winning_matches = df.loc[win_id,:]
    losing_matches = df.loc[loss_id,:]
    
    # Split full name
    first_name, last_name = fullname.split(' ',1)
    
    # Counting stats (should check if names show in correct columns for forfeits, byes, etc.)
    wins = sum(win_id)
    losses = sum(loss_id)
    matches = wins+losses
    
    # Extract weight class, school, etc.
    win_weight = winning_matches['Weight Class'].unique()
    loss_weight = losing_matches['Weight Class'].unique()
    
    if win_weight.size > 0: # Avoiding 'if win_weight:' because it gives truth amibiguity warning
        weight_class = int(win_weight[0])
    else: # !!!Still need to add consideration for multiple weight classes!!!
        weight_class = int(loss_weight[0])
        
    win_school = winning_matches['Winner School (L)'].unique()
    win_school_code = winning_matches['Winner School (S)'].unique()
    loss_school = losing_matches['Loser School (L)'].unique()
    loss_school_code = losing_matches['Loser School (S)'].unique()
    
    if win_school.size > 0: # Avoiding 'if win_school:' because it gives truth amibiguity warning
        school = win_school[0]
        school_code = win_school_code[0]
    else: 
        school = loss_school[0]
        school_code = loss_school_code[0]
        
    # Return list of extracted data 
    return({'First Name':first_name,'Last Name':last_name,'Full Name':fullname,
            'School Name':school,'School Code':school_code,
            'Weight Class':weight_class,'Wins':wins,'Losses':losses,'Matches':matches})

# %%
# Function to create train and test data based on order of wrestling events
# Note: research paper trained on one weight class and tested on all the rest.
# Note: no guarantee test set wrestler will have train data --> implement cold start guess? team average?
# Note: go back and change "Event Order (1=newest)" to "Events Passed"

def train_test_split(match_data,wrestler_data=None, newest=25,oldest=None):
    '''train_test_split takes in full match (and wrestler dataframes?), along with oldest and newest
    pars, which define the range of wrestling events with which to form the train data. Default is most
    recent 25 events makes test set. Returns dict of match_train, match_test, wrestler_train, wrestler_test.'''
    
    # Default oldest to be first event in dataset
    if oldest is None:
        oldest=len(match_data["Event Order (1=newest)"])
    
    # Handle input exceptions        
    if oldest > len(match_data["Event Order (1=newest)"]):
        raise ValueError('Invalid indexing: oldest ({}) cannot be greater than number of events ({})'\
                         .format(oldest,len(match_data["Event Order (1=newest)"])))
    elif newest >= oldest:
        raise ValueError('Invalid indexing: newest ({}) must be less than oldest ({})'\
                         .format(newest,oldest))
        
    else: # Main function code

        # Define train subset index
        train_index = [order in range(newest,oldest+1) for order in MATCHES["Event Order (1=newest)"]]
        test_index = [not index for index in train_index]

        # MATCHES train/test split
        match_train = match_data.loc[train_index]
        match_test = match_data.loc[test_index]
        
        # Name wrestlers to train or test sets
        wrestler_names_train = set(match_train['Winner Full Name']) | set(match_train['Loser Full Name'])
        wrestler_names_train = [x for x in wrestler_names_train if x==x] # remove nan, convert to list
        
        # Not sure if making wrestler test set like this makes total sense but I'll do it for now
        # Maybe because of cumulative stats, wrestler test set is always up-to-date full wrestler data?
        wrestler_names_test = set(match_test['Winner Full Name']) | set(match_test['Loser Full Name'])
        wrestler_names_test = [x for x in wrestler_names_test if x==x] # remove nan, convert to list

        # Call infoscrape to construct wrestler dataframes
        wrestler_train = [infoscrape(wrestler,match_train) for wrestler in wrestler_names_train]
        wrestler_train = pd.DataFrame(wrestler_train)
        wrestler_test = [infoscrape(wrestler,match_test) for wrestler in wrestler_names_test]
        wrestler_test = pd.DataFrame(wrestler_test)
        
        # Store train/test splits in dict
        train_test_dict = {"match_train":match_train,"match_test":match_test,
                          "wrestler_train":wrestler_train,"wrestler_test":wrestler_test}
        
        return(train_test_dict)

# %%
def win_perc_pred(wrestler1,wrestler2,wrestler_train,wrestler_test,match_train,match_test):
    '''win_perc_pred makes a simple prediction that the winner of a match between
    wrestler1 and wrestler2 will be the wrestler with the higher win percentage. Uses wrestlers' fullnames.'''
    
    # Note: this predictor doesn't use match data for now, but I want to 
    # keep the algorithm inputs consistent for evaluation
    
    # Wrestler 1
    wrestler1_bool = wrestler_train["Full Name"]==wrestler1 # should add school clarification step for same names
    
    if sum(wrestler1_bool) == 0: # wrestler not in train set, use their school's average WP
        school_bool = wrestler_test["Full Name"]==wrestler1
        school = wrestler_test.loc[school_bool]["School Name"]
        wrestlers_by_school = wrestler_train.groupby("School Name")
        win_perc_1 = wrestlers_by_school["Wins"].mean().loc[school] / wrestlers_by_school["Matches"].mean().loc[school]
        win_perc_1 = win_perc_1.values
        
    else: # wrestler 1 in train set, has their own WP
        win_perc_1 = wrestler_train.loc[wrestler1_bool]["Wins"] / wrestler_train.loc[wrestler1_bool]["Matches"]
        win_perc_1 = win_perc_1.values

    # Wrestler 2
    wrestler2_bool = wrestler_train["Full Name"]==wrestler2 # should add school clarification step for same names
    
    if sum(wrestler2_bool) == 0: # wrestler not in train set, use their school's average WP
        school_bool = wrestler_test["Full Name"]==wrestler2
        school = wrestler_test.loc[school_bool]["School Name"]
        wrestlers_by_school = wrestler_train.groupby("School Name")
        win_perc_2 = wrestlers_by_school["Wins"].mean().loc[school] / wrestlers_by_school["Matches"].mean().loc[school]
        win_perc_2 = win_perc_2.values
        
    else: # wrestler 2 in train set, has their own WP
        win_perc_2 = wrestler_train.loc[wrestler2_bool]["Wins"] / wrestler_train.loc[wrestler2_bool]["Matches"]
        win_perc_2 = win_perc_2.values
        
    if win_perc_1 > win_perc_2:
        return(wrestler1)
    elif win_perc_1 == win_perc_2:
        return('No Prediction: same win percentage') # TODO: Track these in validation
    else:
        return(wrestler2)

# %%
def test_algorithm(algorithm,match_train,match_test,wrestler_train,wrestler_test):
    '''test_algorithm implements a given algorithm using given wrestler and match 
    train/test data and returns prediction accuracy'''
    
    # Extract matchups from test matches
    test_matchups = []
    
    for i in range(0,match_test.shape[0]):
        match = match_test.loc[i]
        w1 = match["Winner Full Name"]
        w2 = match["Loser Full Name"]
        test_matchups.append((w1,w2))

    # True and predicted winners
    true_winners = match_test["Winner Full Name"] 
    pred_winners = [algorithm(W1,W2,wrestler_train,wrestler_test,match_train,match_test) for W1,W2 in test_matchups]
    
    # Calculate prediction accuracy
    pred_results = true_winners == pred_winners
    pred_accuracy = pred_results.mean()
    
    return(pred_accuracy)

# %%
# See if functions do their job

# %%
# Define train/test sets
train_test_dict = train_test_split(MATCHES) # takes a minute because infoscrape function (can I optimize?)
match_train = train_test_dict["match_train"]
wrestler_train = train_test_dict["wrestler_train"]
match_test = train_test_dict["match_test"]
wrestler_test = train_test_dict["wrestler_test"]

# %%
# Test win percentage algorithm
WP_pred_acc = test_algorithm(win_perc_pred,match_train,match_test,wrestler_train,wrestler_test)
WP_pred_acc
# Out:
# 0.9264705882352942

# %%
# See predictive power of WP on this dataset by shrinking train data size
newest_vals = range(25,56,5)
accuracy_dict = {}

for newest in newest_vals:
    
    train_test_dict = train_test_split(MATCHES,newest=newest)
    match_train = train_test_dict["match_train"]
    wrestler_train = train_test_dict["wrestler_train"]
    match_test = train_test_dict["match_test"]
    wrestler_test = train_test_dict["wrestler_test"]
    
    WP_pred_acc = test_algorithm(win_perc_pred,match_train,match_test,wrestler_train,wrestler_test)
    
    accuracy_dict[newest] = WP_pred_acc
# Out:
# C:\Users\colum\Anaconda3\envs\webscraping\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# C:\Users\colum\Anaconda3\envs\webscraping\lib\site-packages\ipykernel_launcher.py:38: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %%
# Copy-pasted error info when tried to run above chunk past newest=55


# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-fed64846c406> in <module>
#      11     wrestler_test = train_test_dict["wrestler_test"]
#      12 
# ---> 13     WP_pred_acc = test_algorithm(win_perc_pred,match_train,match_test,wrestler_train,wrestler_test)
#      14 
#      15     accuracy_dict[newest] = WP_pred_acc
# 
# <ipython-input-25-6dcb378d74f7> in test_algorithm(algorithm, match_train, match_test, wrestler_train, wrestler_test)
#      14     # True and predicted winners
#      15     true_winners = match_test["Winner Full Name"]
# ---> 16     pred_winners = [algorithm(W1,W2,wrestler_train,wrestler_test,match_train,match_test) for W1,W2 in test_matchups]
#      17 
#      18     # Calculate prediction accuracy
# 
# <ipython-input-25-6dcb378d74f7> in <listcomp>(.0)
#      14     # True and predicted winners
#      15     true_winners = match_test["Winner Full Name"]
# ---> 16     pred_winners = [algorithm(W1,W2,wrestler_train,wrestler_test,match_train,match_test) for W1,W2 in test_matchups]
#      17 
#      18     # Calculate prediction accuracy
# 
# <ipython-input-28-bd598770c4b7> in win_perc_pred(wrestler1, wrestler2, wrestler_train, wrestler_test, match_train, match_test)
#      27         school = wrestler_test.loc[school_bool]["School Name"]
#      28         wrestlers_by_school = wrestler_train.groupby("School Name")
# ---> 29         win_perc_2 = wrestlers_by_school["Wins"].mean().loc[school] / wrestlers_by_school["Matches"].mean().loc[school]
#      30         win_perc_2 = win_perc_2.values
#      31 
# 
# ~\Anaconda3\envs\webscraping\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1764 
#    1765             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1766             return self._getitem_axis(maybe_callable, axis=axis)
#    1767 
#    1768     def _is_scalar_access(self, key: Tuple):
# 
# ~\Anaconda3\envs\webscraping\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1950                     raise ValueError("Cannot index with multidimensional key")
#    1951 
# -> 1952                 return self._getitem_iterable(key, axis=axis)
#    1953 
#    1954             # nested tuple slicing
# 
# ~\Anaconda3\envs\webscraping\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1591         else:
#    1592             # A collection of keys
# -> 1593             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1594             return self.obj._reindex_with_indexers(
#    1595                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
# 
# ~\Anaconda3\envs\webscraping\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1549 
#    1550         self._validate_read_indexer(
# -> 1551             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1552         )
#    1553         return keyarr, indexer
# 
# ~\Anaconda3\envs\webscraping\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1636             if missing == len(indexer):
#    1637                 axis_name = self.obj._get_axis_name(axis)
# -> 1638                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1639 
#    1640             # We (temporarily) allow for some missing keys with .loc, except in
# 
# KeyError: "None of [Index(['George Washington-PSAL'], dtype='object', name='School Name')] are in the [index]"

# %%
# Plot results
plt.bar(range(len(accuracy_dict)), list(accuracy_dict.values()), align='center')
plt.xticks(range(len(accuracy_dict)), list(accuracy_dict.keys()))
plt.title('Prediction Accuracy')
plt.xlabel('n Last Events in Test Set')
plt.ylabel('Accuracy')

# Save fig
plt.savefig('./Plots/win_perc_pred_accuracy.png')

plt.show()

# %%
# Show distribution of number of matches among wrestlers
WRESTLERS.hist(column="Matches")
plt.xlabel("Number of Matches")
plt.ylabel("Number of Wrestlers")
plt.title("Distribution of Wrestlers by Number of Matches")

# Save fig
plt.savefig('./Plots/wrestler_match_dist.png')

# %%
# Show distribution of matches by weight class
wrestlers_by_weight = WRESTLERS.groupby('Weight Class')
wrestlers_by_weight.sum().plot.bar(y="Matches")
plt.title("Distribution of Matches by Weight Class")

# Save fig
plt.savefig('./Plots/matches_by_weight_class.png')

# %%
# Check count of matches by victory type 
# There are 25 nan entries for Victory Type (L)
matches_by_wintype = MATCHES.groupby('Victory Type (L)')
matches_by_wintype.describe()['Match ID'].plot.bar(y='count')
plt.title("Distribution of Wrestlers by Number of Matches")

# Save fig
plt.savefig('./Plots/matches_by_win_type.png')
