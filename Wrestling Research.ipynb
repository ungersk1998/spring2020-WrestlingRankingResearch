# %%
import json
import requests
from bs4 import BeautifulSoup

import re

from selenium import webdriver

import pandas as pd

from random import uniform
from time import sleep

# %%
WRESTLING_URL = 'https://www.trackwrestling.com'

# %%
def cookie_parser(cookie_string):
    ''' 
    Takes in cookie_string from webpage network request headers and reformats it 
    in dictionary form for use as requests.get() cookies parameter
    '''
    
    # Create empty dictionary 
    cookie_dict = {}
    
    # Extracts key-value pairs
    cookie_keys_and_vals = cookie_string.split(';')
    
    # Separates each key and value from its pair and inserts them into cookie_dict dictionary
    for cookie in cookie_keys_and_vals:
        
        split_pair = cookie.split('=',maxsplit=1) # set maxsplit to avoid '=' in cookie value
        cookie_name = split_pair[0].strip() # strip() removes leading/ending whitespace
        
        # Look for cookie names with no values
        if len(split_pair)==2:
            cookie_value = split_pair[1].strip()
        else:
            cookie_value = ''
        
        # Adds cookie to dictionary
        cookie_dict[cookie_name] = cookie_value
        
    return(cookie_dict)

# %%
### Makes cookies to send in request for 2019-2020 NYS High School Boys Wrestling events table
### url: www.trackwrestling.com/seasons/Results.jsp?TIM=1580680176497&twSessionId=aipxyairxr

# raw_cookies are currently copy-pasted; look into scraping them in the future
raw_cookies = '__cfduid=d20db16b722895888e7667a900e31dfbe1579812112; _vwo_uuid_v2=DCC7266DF88C4EB2060E32684740C3214|a420f29d8e0c86e09c05da82b375d0a4; _hjid=9c0d8409-1d58-4e44-8210-90e1bc68af8e; _vwo_uuid=D444C2B39AAEFFC0BB511F3DD82A5D057; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241579812112%3A42.36586452%3A%3A%3A4_0%2C3_0%3A0; _ga=GA1.2.1156555559.1579812115; __qca=P0-2030424604-1579812114847; intercom-id-p4zi0yg9=696e874c-0c6f-471e-89d1-59a32a057909; intercom-session-p4zi0yg9=; __gads=ID=c09932a97005280d:T=1579812116:S=ALNI_MYjvSlVrVU3OVdca9jRWExWIUXJYQ; _1ci_7ag23o86kjasbfd=5d12c791-41fb-11ea-ab95-0b032cabaca3; _MXBj_SURpRlk=33a46ce0-458c-3437-aae2-cf740befb847; _vis_opt_s=4%7C; _vis_opt_test_cookie=1; OX_plg=pm; CRISPKEY=63e5094317006c4bd9675e3; CRISPSUBNO=dbfd5e178002d01cf5b0ef00cdd0460b; _dd_pktn_i=C/1580688794/1580235844/hdvktpgfraalpdm7ym44e3cthbpkxq/2a3b53ff7104af07a5fc4d2fa5b3fc1979ac8135/cncabwc7/129.236.143.187; USER_SESSIONID=C745F9BB61093022BA41D3791EA82379-n5; _gid=GA1.2.726204881.1580911405; _dc_gtm_UA-38689907-1=1; _vwo_sn=1099291%3A10'
baked_cookies = cookie_parser(raw_cookies)

# %%
### Params for using requests.get()

# Params currently copy-pasted; look into scraping them in the future
# Known bug: TIM and/or twSessionId params vary, cannot use old values (quick copy-paste fix for now)
get_params = {
    'TIM': 1580911440115,
    'twSessionId': 'lmvgwklcwx',
    'loadBalanced': 'true',
    'gbId': 38,
    'seasonId': 1428400132
}

# %%
events_request = requests.get(url=WRESTLING_URL+'/seasons'+'/Results.jsp',
                              params=get_params,
                              cookies=baked_cookies)

# %%
# Use regex to extract contents of initDataGrid string from events page response
events_response = events_request.text
initDataGrid_regex = re.compile(r'initDataGrid\(50, true, \"(.*\]\])')
events_data = initDataGrid_regex.findall(events_response)[0]
events_data = re.sub(r'\\','',events_data)
events_data_list = json.loads(events_data)

# Unsure of what every item in each list is. First is eventId, third/fourth is date, 
# then event name, state, and lots of blank entries

# %%
len(events_data_list)
### Notes:
# Events page caps at 250 events, which is roughly the last 5 days. Can't keep scrolling like the indeed page number code
# Maybe need to send specific search params by date?
# unrelated: found creation of TIM parameter in code: TIM="+Math.floor(Math.random()*100000)
# Out:
# 250

# %%
events_data_list
# Out:
# [['5186408132',
#   '1',
#   'I',
#   '20200205',
#   '20200205',
#   'Multi-Meet at Edgemont 2/5/20',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200205',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173527009-New_Panther_Logo_NO_BORDER_(1).png',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5260473132',
#   '0',
#   '',
#   '20200205',
#   '20200205',
#   '',
#   'NY',
#   '1',
#   '778181135',
#   'Rome Free Academy',
#   'NY',
#   '30',
#   '778130135',
#   'Oneida Sr HS',
#   'NY',
#   '28',
#   '0',
#   '0',
#   '20200205',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5002005132',
#   '1',
#   'D',
#   '20200205',
#   '20200205',
#   'Tri Meet vs Stepinac & Iona',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200205',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '',
#   ''],
#  ['5271005132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '777961135',
#   'Gow School',
#   'NY',
#   '40',
#   '778235135',
#   'St Mary`s',
#   'NY',
#   '47',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#800040',
#   '#000080',
#   '#ffffff'],
#  ['5039261132',
#   '1',
#   'I',
#   '20200204',
#   '20200204',
#   'BKW Multi Meet',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200204',
#   None,
#   'O',
#   '545163132',
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5184328132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777874135',
#   'Churchville Chili Sr HS',
#   'NY',
#   '42',
#   '777832135',
#   'Brighton',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000000',
#   '#bf6000',
#   '#000080',
#   '#FFFFFF'],
#  ['5143516132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '777800135',
#   'Arlington',
#   'NY',
#   '6',
#   '778138135',
#   'Our Lady of Lourdes HS',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173279009-7575C931-CAD1-439B-8C0A-0D7D01CD645C.jpeg',
#   'Warriors',
#   '',
#   '#800000',
#   '#ffffff',
#   '#000080',
#   '#808000'],
#  ['5480600132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777784135',
#   'Akron Sr HS',
#   'NY',
#   '46',
#   '777788135',
#   'Alden-Depew Sr HS',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-1149638134-IMG_4217.PNG',
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#0000ff',
#   '#ffff00'],
#  ['5041783132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '778028135',
#   'Jordan-Elbridge Sr HS',
#   'NY',
#   '12',
#   '778068135',
#   'Marcellus',
#   'NY',
#   '64',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5145173132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '777779135',
#   'FDR Hyde Park HS',
#   'NY',
#   '0',
#   '778273135',
#   'Washingtonville Sr HS',
#   'NY',
#   '82',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#008029',
#   '#ffffff',
#   '#000080',
#   '#ffff00'],
#  ['5714363132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778217135',
#   'Somers-North Salem',
#   'NY',
#   '64',
#   '777818135',
#   'Beacon-Haldane HS',
#   'NY',
#   '24',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#db0006',
#   '#b2b2b2',
#   '#000080',
#   '#ffffff'],
#  ['5445188132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778121135',
#   'North Tonawanda Sr HS',
#   'NY',
#   '49',
#   '778317135',
#   'Charter School for Applied Technologies',
#   'NY',
#   '21',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174018009-NT_New_Logo.jpg',
#   None,
#   '',
#   '#000080',
#   '#ff0000',
#   '#000080',
#   '#ffffff'],
#  ['5001565132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777800135',
#   'Arlington',
#   'NY',
#   '62',
#   '778138135',
#   'Our Lady of Lourdes HS',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173279009-7575C931-CAD1-439B-8C0A-0D7D01CD645C.jpeg',
#   'Warriors',
#   '',
#   '#800000',
#   '#ffffff',
#   '#000080',
#   '#808000'],
#  ['5001345132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777876135',
#   'Clarence Sr HS',
#   'NY',
#   '54',
#   '777801135',
#   'Attica-Batavia Sr HS',
#   'NY',
#   '33',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#ff0000',
#   '#000000',
#   '#000080',
#   '#ffffff'],
#  ['5079391132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '778241135',
#   'Sweet Home Sr HS',
#   'NY',
#   '36',
#   '778251135',
#   'Tonawanda Sr HS',
#   'NY',
#   '48',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174275009-zzzzzzzz.png',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#800000',
#   '#ffffff'],
#  ['5444574132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '67',
#   '778232135',
#   'St Joseph By The Sea HS',
#   'NY',
#   '13',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174236009-ST-JOSEPH-BY-THE-SEA-HS-(X-SV).jpg',
#   '',
#   '#800600',
#   '#ffff00',
#   '#000080',
#   '#ffffff'],
#  ['5519987132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778167135',
#   'Putnam Valley',
#   'NY',
#   '54',
#   '778037135',
#   'Lakeland-Panas Sr',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5728242132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '777821135',
#   'Beekmantown Sr HS',
#   'NY',
#   '18',
#   '778150135',
#   'Peru Sr HS',
#   'NY',
#   '54',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#ff0000',
#   '#c0c0c0',
#   '#000080',
#   '#ffffff'],
#  ['5184327132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777874135',
#   'Churchville Chili Sr HS',
#   'NY',
#   '42',
#   '777832135',
#   'Brighton',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000000',
#   '#bf6000',
#   '#000080',
#   '#FFFFFF'],
#  ['5722667132',
#   '1',
#   'I',
#   '20200204',
#   '20200204',
#   'JV Dual Meet - Middletown',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200204',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#808000',
#   '',
#   ''],
#  ['5041496132',
#   '1',
#   'I',
#   '20200204',
#   '20200204',
#   'Last Resort ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200204',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#800000',
#   '',
#   ''],
#  ['5045011132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '778240135',
#   'Susquehanna Valley Sr HS',
#   'NY',
#   '39',
#   '778263135',
#   'Vestal Sr HS',
#   'NY',
#   '44',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5722666132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '778110135',
#   'Newburgh Free Academy',
#   'NY',
#   '33',
#   '778083135',
#   'Middletown Sr HS',
#   'NY',
#   '34',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173926009-M.jpg',
#   '',
#   '#000080',
#   '#808000',
#   '#000080',
#   '#ffffff'],
#  ['5001273132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778105135',
#   'New Paltz Sr HS',
#   'NY',
#   '42',
#   '778265135',
#   'Wallkill Sr HS',
#   'NY',
#   '38',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#800000',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5219967132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778011135',
#   'Iroquois Sr HS',
#   'NY',
#   '55',
#   '778044135',
#   'Letchworth Sr HS',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'https://www.trackwrestling.com/tw/uploads/SS-723580134-IndianColorSmall.png',
#   '',
#   '#ff0000',
#   '#ffffff',
#   '#ff0000',
#   '#ffffff'],
#  ['5001566132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '777800135',
#   'Arlington',
#   'NY',
#   '33',
#   '778174135',
#   'Red Hook Sr HS',
#   'NY',
#   '47',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173279009-7575C931-CAD1-439B-8C0A-0D7D01CD645C.jpeg',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174120009-index.jpeg',
#   '',
#   '#800000',
#   '#ffffff',
#   '#ff0000',
#   '#ffffff'],
#  ['5040900132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '778002135',
#   'Horseheads Sr HS',
#   'NY',
#   '65',
#   '778226135',
#   'SVEC ',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5444572132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '1',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '82',
#   '778232135',
#   'St Joseph By The Sea HS',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174236009-ST-JOSEPH-BY-THE-SEA-HS-(X-SV).jpg',
#   '',
#   '#800600',
#   '#ffff00',
#   '#000080',
#   '#ffffff'],
#  ['5521189132',
#   '0',
#   '',
#   '20200204',
#   '20200204',
#   '',
#   'NY',
#   '2',
#   '778248135',
#   'Stony Brook School',
#   'NY',
#   '6',
#   '778005135',
#   'Huntington HS',
#   'NY',
#   '69',
#   '0',
#   '0',
#   '20200204',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5044144132',
#   '0',
#   '',
#   '20200203',
#   '20200203',
#   '',
#   'NY',
#   '1',
#   '777871135',
#   'Chester Sr HS',
#   'NY',
#   '72',
#   '777779135',
#   'FDR Hyde Park HS',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200203',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173423009-Chester_C_with_Horse_Logo_-_Best_Copy2.png',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#008029',
#   '#ffffff'],
#  ['5142482132',
#   '1',
#   'I',
#   '20200203',
#   '20200203',
#   'Adirondack JV Wrestling Championships',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200203',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5348350132',
#   '1',
#   'I',
#   '20200203',
#   '20200203',
#   'Adirondack League JV Invitational ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200203',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5553818132',
#   '0',
#   '',
#   '20200203',
#   '20200203',
#   '',
#   'NY',
#   '2',
#   '778128135',
#   'Ogdensburg Free Academy HS',
#   'NY',
#   '30',
#   '777960135',
#   'Gouverneur Sr HS',
#   'NY',
#   '48',
#   '0',
#   '0',
#   '20200203',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffff00'],
#  ['5723873132',
#   '0',
#   '',
#   '20200203',
#   '20200203',
#   '',
#   'NY',
#   '1',
#   '777807135',
#   'Avon-Geneseo Sr HS',
#   'NY',
#   '72',
#   '778318135',
#   'Gilead HS',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200203',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5727543132',
#   '1',
#   'I',
#   '20200203',
#   '20200203',
#   'Woodlands Multi Meet',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200203',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5000296132',
#   '1',
#   'D',
#   '20200202',
#   '20200202',
#   'PSAL Dual Meet Championships',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200202',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5186733132',
#   '1',
#   'I',
#   '20200202',
#   '20200202',
#   'JV John Jay Sectional',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200202',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5038054132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Jeff Cuilty Newburgh Duals',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#808000',
#   '',
#   ''],
#  ['5521172132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Mineola quad',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000000',
#   '#ff0000',
#   '',
#   ''],
#  ['5445973132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Mt.Mansville ',
#   'VT',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5002202132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Corinth `Marty Sherman` Tournament',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'O',
#   '553772132',
#   None,
#   '',
#   '',
#   'https://www.trackwrestling.com/tw/uploads/O-553772132-Marty.png',
#   '#ff8040',
#   '#000000',
#   '',
#   ''],
#  ['5265707132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Last Chance Event',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174273009-TC_logo.PNG',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5002210132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Bernie Miller',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'T',
#   '558433132',
#   None,
#   '',
#   '',
#   '',
#   '#000000',
#   '#ff0404',
#   '',
#   ''],
#  ['5040653132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   '`Coach Ken Baker Classic`',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#ff0000',
#   '#ffffff',
#   '',
#   ''],
#  ['5002267132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'State Dual Meet Tournament',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5217498132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Farmingdale Varsity Timmy Collins Invitational',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'P',
#   '579301132',
#   None,
#   '',
#   '',
#   '',
#   '#07ac28',
#   '#ffffff',
#   '',
#   ''],
#  ['5002014132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'CHSAA-NYC Multi Meet',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5588394132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'John Jay JV Tournament',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173769009-John_Jay_AIA-mock_final.jpg',
#   '#000080',
#   '#FFFFFF',
#   '',
#   ''],
#  ['5444595132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Fordham multi meet',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5036635132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'South Side Duals ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ff0000',
#   '',
#   ''],
#  ['5004995132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Paul DiIorio Memorial Tournament',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'P',
#   '549690132',
#   None,
#   '',
#   '',
#   '',
#   '#e10000',
#   '#f4e95e',
#   '',
#   ''],
#  ['5002372132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Liberty/Patriot League',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173688009-Homer_Wrestling_Trojan-_Picture.jpg',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5002135132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'CSC  League Tournament ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'O',
#   '530745132',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5519270132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Locust Valley Invitational',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#008000',
#   '#ffffff',
#   '',
#   ''],
#  ['5726342132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Port Jefferson Multi Team Event',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '',
#   ''],
#  ['5035561132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '2',
#   '777989135',
#   'Hewlett',
#   'NY',
#   '24',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '33',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#800600',
#   '#ffff00'],
#  ['5726394132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '1',
#   '777925135',
#   'Edward R. Murrow  - PSAL',
#   'NY',
#   '45',
#   '778077135',
#   'McKee-Staten Island Tech-PSAL',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#008000',
#   '#ffffff',
#   '#000000',
#   '#808000'],
#  ['5726034132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Blended PSAL Dual Championship ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5079222132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'NYSPHSAA Dual Meet Championships',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'T',
#   '502994132',
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/P-146530009-nysphsaa_logo1.png',
#   None,
#   None,
#   '',
#   ''],
#  ['5177741132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Bethlehem JV Duals',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5186406132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Multi-Meet at Edgemont 2/1/20',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173527009-New_Panther_Logo_NO_BORDER_(1).png',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5480534132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'PA',
#   '1',
#   '901252135',
#   'Wyoming Seminary',
#   'PA',
#   '78',
#   '778256135',
#   'Union-Endicott Sr HS',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6182215009-unnamed.jpg',
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#ff8000',
#   '#000000'],
#  ['5003882132',
#   '1',
#   'I',
#   '20200131',
#   '20200201',
#   'JV counties',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5142671132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Walt Peterson Memorial Tournament  (Avoca Invitational)',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'P',
#   '578903132',
#   None,
#   '',
#   '',
#   '',
#   '#800000',
#   '#ffffff',
#   '',
#   ''],
#  ['5002231132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'WDA JV Tournament',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#ff8000',
#   '#070707',
#   '',
#   ''],
#  ['5040488132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'Oyster Bay Duals',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5180391132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'ECIC JV Championships',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'O',
#   '579369132',
#   None,
#   '',
#   '',
#   'null',
#   '#ecac2d',
#   '#030000',
#   '',
#   ''],
#  ['5727825132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '2',
#   '777925135',
#   'Edward R. Murrow  - PSAL',
#   'NY',
#   '24',
#   '778239135',
#   'Susan Wagner-PSAL',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#008000',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5177082132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Wes Dolson Invitational',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   'P',
#   '578915132',
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5726330132',
#   '1',
#   'D',
#   '20200201',
#   '20200201',
#   'PSAL Team Championships',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5035560132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '2',
#   '777989135',
#   'Hewlett',
#   'NY',
#   '15',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '78',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#800600',
#   '#ffff00'],
#  ['5000181132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'IVY PREP TOURNAMENT',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5726726132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '2',
#   '777925135',
#   'Edward R. Murrow  - PSAL',
#   'NY',
#   '0',
#   '778252135',
#   'Tottenville-PSAL',
#   'NY',
#   '82',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#008000',
#   '#ffffff',
#   '#480f83',
#   '#ffffff'],
#  ['5441911132',
#   '0',
#   '',
#   '20200201',
#   '20200201',
#   '',
#   'NY',
#   '1',
#   '778109135',
#   'Newark Valley Sr HS',
#   'NY',
#   '60',
#   '777902135',
#   'Deposit-Hancock HS',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200201',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#8000ff',
#   '#ffffff'],
#  ['5725985132',
#   '1',
#   'I',
#   '20200201',
#   '20200201',
#   'Jeff Cuilty Newburgh Duals Exhibition',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200201',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5002071132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778304135',
#   'Yonkers City Schools',
#   'NY',
#   '48',
#   '777981135',
#   'Harrison',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#800040',
#   '#ffffff'],
#  ['5588405132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778167135',
#   'Putnam Valley',
#   'NY',
#   '48',
#   '778138135',
#   'Our Lady of Lourdes HS',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'Warriors',
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#808000'],
#  ['5445922132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777876135',
#   'Clarence Sr HS',
#   'NY',
#   '72',
#   '778111135',
#   'Newfane Sr HS',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#ff0000',
#   '#000000',
#   '#000080',
#   '#ffffff'],
#  ['5041472132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778307135',
#   'Dalton School',
#   'NY',
#   '48',
#   '778248135',
#   'Stony Brook School',
#   'NY',
#   '34',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5181281132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777793135',
#   'Amherst Sr HS',
#   'NY',
#   '64',
#   '778241135',
#   'Sweet Home Sr HS',
#   'NY',
#   '17',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173265009-Black_Tiger.JPG',
#   None,
#   '',
#   '#ecac2d',
#   '#030000',
#   '#000080',
#   '#FFFFFF'],
#  ['5346773132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777912135',
#   'East Aurora-Holland HS',
#   'NY',
#   '49',
#   '778036135',
#   'Lake Shore HS',
#   'NY',
#   '31',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173801009-eagles.JPG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#008000',
#   '#ffffff'],
#  ['5178131132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778144135',
#   'Pavilion-York Sr HS',
#   'NY',
#   '18',
#   '777789135',
#   'Alexander Sr HS',
#   'NY',
#   '59',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5346780132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777912135',
#   'East Aurora-Holland HS',
#   'NY',
#   '12',
#   '778036135',
#   'Lake Shore HS',
#   'NY',
#   '3',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173801009-eagles.JPG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#008000',
#   '#ffffff'],
#  ['5077594132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'CT',
#   '1',
#   '1066236135',
#   'Fairfield-Ward HS',
#   'CT',
#   '72',
#   '778026135',
#   'John Jay Sr -Cross River HS',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173769009-John_Jay_AIA-mock_final.jpg',
#   '',
#   None,
#   None,
#   '#000080',
#   '#FFFFFF'],
#  ['5724026132',
#   '1',
#   'D',
#   '20200131',
#   '20200131',
#   'Waren Hines Duels',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200131',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5551922132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778255135',
#   'Unadilla Valley-Unatego Sr HS',
#   'NY',
#   '57',
#   '777902135',
#   'Deposit-Hancock HS',
#   'NY',
#   '13',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#8000ff',
#   '#ffffff'],
#  ['5037078132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778317135',
#   'Charter School for Applied Technologies',
#   'NY',
#   '27',
#   '778058135',
#   'Lyndonville Central School',
#   'NY',
#   '60',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-723594134-Lyndonville_Wrestling_w%2F_words.png',
#   '',
#   '#000080',
#   '#ffffff',
#   '#df7000',
#   '#000000'],
#  ['5036634132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778222135',
#   'South East Cyclones HS',
#   'NY',
#   '59',
#   '778184135',
#   'Roslyn',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ff0000',
#   '#000080',
#   '#ffffff'],
#  ['5186404132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777924135',
#   'Edgemont Sr',
#   'NY',
#   '60',
#   '778198135',
#   'Scarsdale Sr',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173527009-New_Panther_Logo_NO_BORDER_(1).png',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#6d040a',
#   '#ffffff'],
#  ['5035559132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '75',
#   '777890135',
#   'Copiague',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#800600',
#   '#ffff00',
#   '#000080',
#   '#ffffff'],
#  ['5003971132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778190135',
#   'Sachem  North',
#   'NY',
#   '50',
#   '778112135',
#   'Newfield Sr HS',
#   'NY',
#   '23',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174150009-Arrowhead.jpg',
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#ff160a',
#   '#ffffff'],
#  ['5250574132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778087135',
#   'Mineola',
#   'NY',
#   '27',
#   '778281135',
#   'Mepham (Wellington C) HS',
#   'NY',
#   '15',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174341009-2016_Maroon.jpg',
#   '',
#   '#000000',
#   '#ff0000',
#   '#6a0000',
#   '#808080'],
#  ['5040522132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778000135',
#   'Horace Greeley',
#   'NY',
#   '38',
#   '778145135',
#   'Pawling Sr',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#ff8040',
#   '#000000'],
#  ['5039997132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778235135',
#   'St Mary`s',
#   'NY',
#   '15',
#   '778286135',
#   'West Seneca East-West Sr HS',
#   'NY',
#   '63',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffff00'],
#  ['5250217132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778191135',
#   'St Francis',
#   'NY',
#   '39',
#   '778233135',
#   'St Joseph Collegiate Institute',
#   'NY',
#   '45',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5726004132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778116135',
#   'North Babylon Sr High Sch',
#   'NY',
#   '33',
#   '778257135',
#   'Uniondale Sr',
#   'NY',
#   '34',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000000',
#   '#ffff00'],
#  ['5725969132',
#   '1',
#   'I',
#   '20200131',
#   '20200131',
#   'St Francis Dual Exhibition',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200131',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5721966132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778215135',
#   'Smithtown HS East',
#   'NY',
#   '49',
#   '778216135',
#   'Smithtown HS West',
#   'NY',
#   '25',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5143830132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777863135',
#   'Central Islip Sr HS',
#   'NY',
#   '40',
#   '778285135',
#   'West Islip Sr High',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#feff26'],
#  ['5001606132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'CT',
#   '1',
#   '901323135',
#   'Hopkins School',
#   'CT',
#   '63',
#   '778310135',
#   'Rye Country Day School',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5179627132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '777827135',
#   'Bethpage',
#   'NY',
#   '28',
#   '777842135',
#   'Calhoun Sr High',
#   'NY',
#   '38',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173365009-Screenshot_20171025-230051.png',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5727443132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'CT',
#   '2',
#   '1581398138',
#   'NEW CANAAN',
#   'CT',
#   '6',
#   '778026135',
#   'John Jay Sr -Cross River HS',
#   'NY',
#   '76',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173769009-John_Jay_AIA-mock_final.jpg',
#   '',
#   None,
#   None,
#   '#000080',
#   '#FFFFFF'],
#  ['5038053132',
#   '1',
#   'D',
#   '20200131',
#   '20200131',
#   'Newburgh JV Duals',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200131',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#808000',
#   '',
#   ''],
#  ['5445180132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '777868135',
#   'Cheektowaga Sr HS',
#   'NY',
#   '12',
#   '777784135',
#   'Akron Sr HS',
#   'NY',
#   '70',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-1149638134-IMG_4217.PNG',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#FFFFFF'],
#  ['5004999132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778189135',
#   'Sachem  East',
#   'NY',
#   '63',
#   '778283135',
#   'West Babylon Sr HS',
#   'NY',
#   '22',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-723727134-th.jpeg',
#   None,
#   '',
#   '#e10000',
#   '#f4e95e',
#   '#000080',
#   '#ffffff'],
#  ['5035558132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777866135',
#   'Chaminade',
#   'NY',
#   '42',
#   '777890135',
#   'Copiague',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#800600',
#   '#ffff00',
#   '#000080',
#   '#ffffff'],
#  ['5186405132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777924135',
#   'Edgemont Sr',
#   'NY',
#   '18',
#   '778198135',
#   'Scarsdale Sr',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173527009-New_Panther_Logo_NO_BORDER_(1).png',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#6d040a',
#   '#ffffff'],
#  ['5004055132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778123135',
#   'Northport Sr High',
#   'NY',
#   '51',
#   '777916135',
#   'East Islip HS',
#   'NY',
#   '25',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffff00',
#   '#000080',
#   '#FFFFFF'],
#  ['5003844132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778116135',
#   'North Babylon Sr High Sch',
#   'NY',
#   '36',
#   '778257135',
#   'Uniondale Sr',
#   'NY',
#   '37',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000000',
#   '#ffff00'],
#  ['5253715132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '777900135',
#   'Deer Park HS',
#   'NY',
#   '62',
#   '777794135',
#   'Amityville Memorial HS',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#692346',
#   '#aaaaaa',
#   '#000080',
#   '#ffffff'],
#  ['5725377132',
#   '1',
#   'I',
#   '20200131',
#   '20200131',
#   'Hastings Multi Meet',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200131',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   ''],
#  ['5713961132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '1',
#   '778136135',
#   'Oswego Sr HS',
#   'NY',
#   '60',
#   '777894135',
#   'Cortland Sr HS',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174042009-buc.gif',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173469009-Cortland.png',
#   '',
#   '#0000ff',
#   '#ffffff',
#   '#380071',
#   '#ffffff'],
#  ['5003069132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '777996135',
#   'Holy Trinity',
#   'NY',
#   '38',
#   '778231135',
#   'St John The Baptist Hs',
#   'NY',
#   '48',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   'https://pbs.twimg.com/profile_images/890189593622065152/HswNozFN_400x400.jpg',
#   'www.stjohnthebaptistdhs.org',
#   '',
#   '#008040',
#   '#ffffff',
#   '#000080',
#   '#c6011f'],
#  ['5250572132',
#   '0',
#   '',
#   '20200131',
#   '20200131',
#   '',
#   'NY',
#   '2',
#   '778087135',
#   'Mineola',
#   'NY',
#   '35',
#   '778281135',
#   'Mepham (Wellington C) HS',
#   'NY',
#   '47',
#   '0',
#   '0',
#   '20200131',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174341009-2016_Maroon.jpg',
#   '',
#   '#000000',
#   '#ff0000',
#   '#6a0000',
#   '#808080'],
#  ['5447145132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778018135',
#   'Jamestown HS',
#   'NY',
#   '24',
#   '777977135',
#   'Hamburg Sr HS',
#   'NY',
#   '51',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#400080',
#   '#ffffff'],
#  ['5002073132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777981135',
#   'Harrison',
#   'NY',
#   '29',
#   '778161135',
#   'Port Chester Sr',
#   'NY',
#   '57',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#800040',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5182059132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777935135',
#   'Fillmore Sr HS',
#   'NY',
#   '18',
#   '777806135',
#   'Avoca Sr HS',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#800000',
#   '#ffffff'],
#  ['5521830132',
#   '1',
#   'I',
#   '20200130',
#   '20200130',
#   'CS Viking Multi Team Event',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200130',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#802800',
#   '#ffffff',
#   '',
#   ''],
#  ['5145893132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777852135',
#   'Canton HS',
#   'NY',
#   '22',
#   '777960135',
#   'Gouverneur Sr HS',
#   'NY',
#   '57',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#800002',
#   '#ffffff',
#   '#000080',
#   '#ffff00'],
#  ['5447485132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778058135',
#   'Lyndonville Central School',
#   'NY',
#   '22',
#   '777787135',
#   'Albion HS',
#   'NY',
#   '56',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-723594134-Lyndonville_Wrestling_w%2F_words.png',
#   None,
#   '',
#   '#df7000',
#   '#000000',
#   '#000080',
#   '#ffffff'],
#  ['5046084132',
#   '1',
#   'D',
#   '20200130',
#   '20200130',
#   'Martin Luther ',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200130',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   '',
#   '#000080',
#   '#ffffff',
#   '',
#   ''],
#  ['5145955132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777999135',
#   'Hoosick Falls Sr',
#   'NY',
#   '39',
#   '777965135',
#   'Granville Sr HS',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5182953132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777938135',
#   'Fordham Preparatory School',
#   'NY',
#   '12',
#   '778117135',
#   'North Rockland',
#   'NY',
#   '72',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5037954132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777949135',
#   'Galway Sr HS',
#   'NY',
#   '12',
#   '777846135',
#   'Canajoharie-Fort Plain',
#   'NY',
#   '39',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000000',
#   '#ffffff'],
#  ['5002206132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778188135',
#   'Rye',
#   'NY',
#   '60',
#   '778098135',
#   'Mount Vernon',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000000',
#   '#ff0404',
#   '#000080',
#   '#ffffff'],
#  ['5039448132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777962135',
#   'Gowanda Sr HS',
#   'NY',
#   '60',
#   '777859135',
#   'Cattaraugus-Little Valley Sr HS',
#   'NY',
#   '10',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'https://www.trackwrestling.com/tw/uploads/SS-777962135-LogoWrest.jpg',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5179316132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778015135',
#   'Ithaca Sr HS',
#   'NY',
#   '18',
#   '777969135',
#   'Oxford-Greene',
#   'NY',
#   '64',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#800000',
#   '#ffff00',
#   '#808080',
#   '#000000'],
#  ['5002001132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778009135',
#   'Iona Prep',
#   'NY',
#   '78',
#   '778303135',
#   'Xavier',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5042115132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777986135',
#   'Hendrick Hudson',
#   'NY',
#   '39',
#   '778158135',
#   'Pleasantville Sr',
#   'NY',
#   '40',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'Panther',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#008040',
#   '#ffffff'],
#  ['5038008132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778197135',
#   'Sayville',
#   'NY',
#   '56',
#   '777817135',
#   'Bayport-Blue Point HS',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'https://www.trackwrestling.com/tw/uploads/SS-777817135-86CBB243-DDBF-4D09-A38C-100397ECCF4F.jpeg',
#   '',
#   '#8000ff',
#   '#fadb05',
#   '#000080',
#   '#d19d01'],
#  ['5552343132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778284135',
#   'West Genesee Sr HS',
#   'NY',
#   '42',
#   '778118135',
#   'North Rose-Wolcott',
#   'NY',
#   '39',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#00376f',
#   '#ffff00',
#   '#004000',
#   '#ffffff'],
#  ['5519995132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778037135',
#   'Lakeland-Panas Sr',
#   'NY',
#   '58',
#   '778289135',
#   'White Plains Sr',
#   'NY',
#   '24',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5000803132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777860135',
#   'Cazenovia Sr HS',
#   'NY',
#   '12',
#   '778049135',
#   'Liverpool',
#   'NY',
#   '61',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5714719132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778053135',
#   'Long Beach Sr',
#   'NY',
#   '33',
#   '777989135',
#   'Hewlett',
#   'NY',
#   '37',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5254944132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778034135',
#   'La Salle Institute (Sr)',
#   'NY',
#   '36',
#   '777786135',
#   'Albany Academy',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#080000',
#   '#d00227'],
#  ['5520628132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777993135',
#   'Hilton',
#   'NY',
#   '40',
#   '778187135',
#   'Rush-Henrietta Sr',
#   'NY',
#   '38',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000000',
#   '#ff0000',
#   '#000080',
#   '#ffffff'],
#  ['5518501132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777864135',
#   'Central Square HS',
#   'NY',
#   '72',
#   '778136135',
#   'Oswego Sr HS',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-723398134-CentralSquarelogo.jpg',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174042009-buc.gif',
#   '',
#   '#800000',
#   '#ffffff',
#   '#0000ff',
#   '#ffffff'],
#  ['5040669132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778079135',
#   'Mechanicville-Stillwater Sr HS',
#   'NY',
#   '18',
#   '777843135',
#   'Salem-Cambridge Sr HS',
#   'NY',
#   '63',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#ff0000',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5001340132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777801135',
#   'Attica-Batavia Sr HS',
#   'NY',
#   '43',
#   '777847135',
#   'Canandaigua Academy',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#ff0000',
#   '#808080'],
#  ['5002370132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777808135',
#   'Babylon Sr HS',
#   'NY',
#   '0',
#   '778013135',
#   'Island Trees Sr High',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173732009-BullDog-Competitor-600x567.jpg',
#   '',
#   '#000080',
#   '#ffffff',
#   '#cc0000',
#   '#ffffff'],
#  ['5520752132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778021135',
#   'Jericho Sr High',
#   'NY',
#   '55',
#   '777967135',
#   'Great Neck South HS',
#   'NY',
#   '33',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173610009-image1.PNG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ff8000'],
#  ['5410694132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777764135',
#   'Seward Park - PSAL',
#   'NY',
#   '36',
#   '777813135',
#   'Baruch College Campus-PSAL',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5727040132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778020135',
#   'Jasper-Troupsburg',
#   'NY',
#   '15',
#   '777845135',
#   'Campbell-Savona Sr HS',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000000',
#   '#909090',
#   '#000080',
#   '#ffffff'],
#  ['5001450132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '777795135',
#   'Amsterdam',
#   'NY',
#   '47',
#   '777974135',
#   'Hadley Luzerne-Lake George HS',
#   'NY',
#   '26',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#400040',
#   '#ffff00',
#   '#000080',
#   '#ffffff'],
#  ['5001297132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778063135',
#   'Mamaroneck',
#   'NY',
#   '57',
#   '777878135',
#   'Clarkstown North Sr HS',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000000',
#   '#800080'],
#  ['5516973132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '1',
#   '778060135',
#   'Mahopac',
#   'NY',
#   '69',
#   '778000135',
#   'Horace Greeley',
#   'NY',
#   '12',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5717471132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '777960135',
#   'Gouverneur Sr HS',
#   'NY',
#   '36',
#   '778219135',
#   'South Jefferson-Sandy Creek Sr HS',
#   'NY',
#   '43',
#   '0',
#   '0',
#   '20200130',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   None,
#   '',
#   '#000080',
#   '#ffff00',
#   '#000000',
#   '#ffffff'],
#  ['5144083132',
#   '1',
#   'I',
#   '20200130',
#   '20200130',
#   'Minisink Valley/Saugerties JV',
#   'NY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '20200130',
#   None,
#   None,
#   None,
#   None,
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174120009-index.jpeg',
#   '#ff0000',
#   '#ffffff',
#   '',
#   ''],
#  ['5077764132',
#   '0',
#   '',
#   '20200130',
#   '20200130',
#   '',
#   'NY',
#   '2',
#   '778232135',
# ...
#   '36',
#   '778159135',
#   'Poland- W Canada-Remsen',
#   'NY',
#   '18',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174090009-_logo.png',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ff8000'],
#  ['5143554132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777861135',
#   'Center Moriches HS',
#   'NY',
#   '26',
#   '777815135',
#   'Bay Shore Sr HS',
#   'NY',
#   '52',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#d90000',
#   '#000000',
#   '#000080',
#   '#FFFFFF'],
#  ['5038905132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777869135',
#   'Chenango Forks HS',
#   'NY',
#   '61',
#   '778250135',
#   'Tioga Sr HS',
#   'NY',
#   '22',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6174273009-TC_logo.PNG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5001999132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778009135',
#   'Iona Prep',
#   'NY',
#   '30',
#   '778106135',
#   'New Rochelle Sr HS',
#   'NY',
#   '42',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5260577132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777870135',
#   'Chenango Valley Sr HS',
#   'NY',
#   '24',
#   '778027135',
#   'Johnson City Sr HS',
#   'NY',
#   '45',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#FFFFFF'],
#  ['5553907132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778173135',
#   'Red Creek Sr HS',
#   'NY',
#   '21',
#   '778118135',
#   'North Rose-Wolcott',
#   'NY',
#   '51',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#004000',
#   '#ffffff'],
#  ['5264048132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778220135',
#   'South Lewis Sr HS',
#   'NY',
#   '33',
#   '778219135',
#   'South Jefferson-Sandy Creek Sr HS',
#   'NY',
#   '42',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174214009-falcon_1_chenille_mascot_patch__24612.1406691514.380.500.jpg',
#   None,
#   '',
#   '#ff0000',
#   '#ffffff',
#   '#000000',
#   '#ffffff'],
#  ['5554189132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778082135',
#   'Mexico',
#   'NY',
#   '48',
#   '777997135',
#   'Homer Sr HS',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173688009-Homer_Wrestling_Trojan-_Picture.jpg',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5143484132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778044135',
#   'Letchworth Sr HS',
#   'NY',
#   '48',
#   '778271135',
#   'Warsaw Sr HS',
#   'NY',
#   '33',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'https://www.trackwrestling.com/tw/uploads/SS-723580134-IndianColorSmall.png',
#   None,
#   '',
#   '#ff0000',
#   '#ffffff',
#   '#ff8000',
#   '#000000'],
#  ['5556609132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778150135',
#   'Peru Sr HS',
#   'NY',
#   '49',
#   '778122135',
#   'Northern Adirondack Sr HS',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5044406132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778255135',
#   'Unadilla Valley-Unatego Sr HS',
#   'NY',
#   '27',
#   '777809135',
#   'BGAH',
#   'NY',
#   '53',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5002181132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778280135',
#   'Webster Thomas',
#   'NY',
#   '48',
#   '777931135',
#   'Fairport Sr HS',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffffff',
#   '#ff0000',
#   '#0000ff'],
#  ['5078701132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778281135',
#   'Mepham (Wellington C) HS',
#   'NY',
#   '60',
#   '777827135',
#   'Bethpage',
#   'NY',
#   '24',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174341009-2016_Maroon.jpg',
#   None,
#   '',
#   '#6a0000',
#   '#808080',
#   '#000080',
#   '#FFFFFF'],
#  ['5041684132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777940135',
#   'Fox Lane',
#   'NY',
#   '53',
#   '778238135',
#   'Suffern Sr HS',
#   'NY',
#   '23',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5722235132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778225135',
#   'Southwestern HS',
#   'NY',
#   '0',
#   '777962135',
#   'Gowanda Sr HS',
#   'NY',
#   '0',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'https://www.trackwrestling.com/tw/uploads/SS-777962135-LogoWrest.jpg',
#   '',
#   '#000080',
#   '#ff0000',
#   '#000080',
#   '#ffffff'],
#  ['5142270132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778284135',
#   'West Genesee Sr HS',
#   'NY',
#   '51',
#   '777934135',
#   'Fayetteville-Manlius Sr HS',
#   'NY',
#   '27',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#00376f',
#   '#ffff00',
#   '#008040',
#   '#ffffff'],
#  ['5001272132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777893135',
#   'Cornwall Sr HS',
#   'NY',
#   '28',
#   '778105135',
#   'New Paltz Sr HS',
#   'NY',
#   '48',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#0d8000',
#   '#ffffff',
#   '#800000',
#   '#ffffff'],
#  ['5003482132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777833135',
#   'Brockport',
#   'NY',
#   '27',
#   '777993135',
#   'Hilton',
#   'NY',
#   '41',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000000',
#   '#ff0000'],
#  ['5004050132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778123135',
#   'Northport Sr High',
#   'NY',
#   '43',
#   '777885135',
#   'Commack',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#ffff00',
#   '#0a0202',
#   '#ffffff'],
#  ['5003673132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777980135',
#   'Harborfields',
#   'NY',
#   '9',
#   '778211135',
#   'Shoreham-Wading River HS',
#   'NY',
#   '77',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5079110132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778273135',
#   'Washingtonville Sr HS',
#   'NY',
#   '0',
#   '778088135',
#   'Minisink Valley',
#   'NY',
#   '0',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffff00',
#   '#004000',
#   '#ffffff'],
#  ['5142427132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778155135',
#   'Pittsford HS',
#   'NY',
#   '27',
#   '778187135',
#   'Rush-Henrietta Sr',
#   'NY',
#   '38',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#ffffff'],
#  ['5080100132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778184135',
#   'Roslyn',
#   'NY',
#   '43',
#   '777966135',
#   'Great Neck North Sr High',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   'http://www.trackwrestling.com/tw/uploads/SS-723499134-Goat_Logo_new-_2018_(1).JPG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5141815132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777998135',
#   'Honeoye Falls-Lima Sr HS',
#   'NY',
#   '52',
#   '777911135',
#   'East HS (Sota-NE-NW College Prep-Vanguard)',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173691009-cougarheadlogo.jpg',
#   'http://www.trackwrestling.com/tw/uploads/',
#   '',
#   '#e1e100',
#   '#070707',
#   '#000080',
#   '#ffffff'],
#  ['5040665132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777974135',
#   'Hadley Luzerne-Lake George HS',
#   'NY',
#   '36',
#   '778079135',
#   'Mechanicville-Stillwater Sr HS',
#   'NY',
#   '29',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#ff0000',
#   '#ffffff'],
#  ['5185980132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778024135',
#   'John H Glenn HS',
#   'NY',
#   '9',
#   '778064135',
#   'Manhasset Sr HS',
#   'NY',
#   '67',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5001337132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778264135',
#   'Victor Sr HS',
#   'NY',
#   '42',
#   '777801135',
#   'Attica-Batavia Sr HS',
#   'NY',
#   '37',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5001198132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777871135',
#   'Chester Sr HS',
#   'NY',
#   '72',
#   '777836135',
#   'Burke Catholic HS',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173423009-Chester_C_with_Horse_Logo_-_Best_Copy2.png',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5000576132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778195135',
#   'Saratoga Springs Sr HS',
#   'NY',
#   '21',
#   '778209135',
#   'Shenendehowa',
#   'NY',
#   '54',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'https://www.trackwrestling.com/tw/uploads/SS-778195135-Blue_Streaks.jpg',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#004000',
#   '#ffffff'],
#  ['5002570132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778174135',
#   'Red Hook Sr HS',
#   'NY',
#   '36',
#   '777991135',
#   'Highland Sr HS',
#   'NY',
#   '39',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174120009-index.jpeg',
#   None,
#   '',
#   '#ff0000',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5719625132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778205135',
#   'Seaford Sr High',
#   'NY',
#   '18',
#   '778157135',
#   'Plainview-Old Bethpage Jfk HS',
#   'NY',
#   '6',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#00ff00',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5035530132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778003135',
#   'Hudson Falls Sr HS',
#   'NY',
#   '60',
#   '777891135',
#   'Corinth Sr HS',
#   'NY',
#   '25',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#008000',
#   '#ffffff',
#   '#ff8040',
#   '#000000'],
#  ['5253838132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778028135',
#   'Jordan-Elbridge Sr HS',
#   'NY',
#   '42',
#   '778160135',
#   'Port Byron-US',
#   'NY',
#   '37',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#ffffff'],
#  ['5004340132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778231135',
#   'St John The Baptist Hs',
#   'NY',
#   '67',
#   '777985135',
#   'Hempstead',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'www.stjohnthebaptistdhs.org',
#   None,
#   '',
#   '#000080',
#   '#c6011f',
#   '#000080',
#   '#ffffff'],
#  ['5002265132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777847135',
#   'Canandaigua Academy',
#   'NY',
#   '36',
#   '778279135',
#   'Wayne Sr HS',
#   'NY',
#   '24',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174337009-eagle.jpg',
#   '',
#   '#ff0000',
#   '#808080',
#   '#000080',
#   '#ffff00'],
#  ['5349408132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778041135',
#   'Lawrence Sr High',
#   'NY',
#   '48',
#   '778206135',
#   'Sewanhaka West',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173816009-Lawrence_Tornado.jpg',
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#7d1165',
#   '#0c0c0c'],
#  ['5445504132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778114135',
#   'Niagara Wheatfield Sr HS',
#   'NY',
#   '78',
#   '778046135',
#   'Lewiston Porter Sr HS',
#   'NY',
#   '9',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000000',
#   '#ffffff',
#   '#00ff00',
#   '#ffffff'],
#  ['5004425132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778012135',
#   'Irvington',
#   'NY',
#   '39',
#   '778138135',
#   'Our Lady of Lourdes HS',
#   'NY',
#   '36',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'Warriors',
#   '',
#   '#000080',
#   '#FFFFFF',
#   '#000080',
#   '#808000'],
#  ['5080200132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '777788135',
#   'Alden-Depew Sr HS',
#   'NY',
#   '29',
#   '778297135',
#   'Williamsville South HS',
#   'NY',
#   '51',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#0000ff',
#   '#ffff00',
#   '#000080',
#   '#FFFFFF'],
#  ['5256115132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778007135',
#   'Indian River-SH',
#   'NY',
#   '49',
#   '777820135',
#   'Beaver River Sr HS',
#   'NY',
#   '33',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173717009-IRCSD_Spear_Logo_Hi_Res.jpg',
#   None,
#   '',
#   '#000040',
#   '#75d2ff',
#   '#008000',
#   '#ff8000'],
#  ['5078165132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778235135',
#   'St Mary`s',
#   'NY',
#   '37',
#   '778241135',
#   'Sweet Home Sr HS',
#   'NY',
#   '48',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#000080',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5445710132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778223135',
#   'Southampton Sr High',
#   'NY',
#   '24',
#   '778288135',
#   'Westhampton Beach Sr',
#   'NY',
#   '58',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/',
#   None,
#   '',
#   '#400000',
#   '#ffffff',
#   '#000080',
#   '#FFFFFF'],
#  ['5044159132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '2',
#   '778182135',
#   'Rondout Valley Sr HS',
#   'NY',
#   '3',
#   '778163135',
#   'Port Jervis  Sr HS',
#   'NY',
#   '84',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#0000a0',
#   '#000000',
#   '#f00000',
#   '#000000'],
#  ['5177175132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778197135',
#   'Sayville',
#   'NY',
#   '35',
#   '777916135',
#   'East Islip HS',
#   'NY',
#   '34',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   None,
#   '',
#   '#8000ff',
#   '#fadb05',
#   '#000080',
#   '#FFFFFF'],
#  ['5038510132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '777973135',
#   'Guilderland',
#   'NY',
#   '54',
#   '778115135',
#   'Niskayuna',
#   'NY',
#   '30',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   'http://www.trackwrestling.com/tw/uploads/SS-6173626009-G-Banner.png',
#   'http://www.trackwrestling.com/tw/uploads/SS-6174001009-1_0.jpg',
#   '',
#   '#e71631',
#   '#ffffff',
#   '#ff0000',
#   '#9f9f9f'],
#  ['5145879132',
#   '0',
#   '',
#   '20200129',
#   '20200129',
#   '',
#   'NY',
#   '1',
#   '778154135',
#   'Pioneer Sr HS',
#   'NY',
#   '64',
#   '778036135',
#   'Lake Shore HS',
#   'NY',
#   '19',
#   '0',
#   '0',
#   '20200129',
#   None,
#   '',
#   '',
#   '',
#   None,
#   'http://www.trackwrestling.com/tw/uploads/SS-6173801009-eagles.JPG',
#   '',
#   '#000080',
#   '#ffffff',
#   '#008000',
#   '#ffffff']]

# %%
### Remote browsing through selenium

driver = webdriver.Firefox()
driver.implicitly_wait(uniform(0.1,0.5)) # force random wait time between 100-500 ms
driver.get(WRESTLING_URL)

# %%
### The following cells navigate from trackwrestling landing page to New York State meets pages

# %%
driver.execute_script("displayMenu('subMenu-browse', 'left', 1, 'Browse')")

# %%
driver.execute_script("displayMenu('subMenu-seasons', 'left', 2, 'Seasons')")

# %%
driver.execute_script("displayMenu('subMenu-seasonOrganizeBy_1428400132', 'left', 3, '2019-20 High School Boys')")

# %%
driver.execute_script("gotoBuildURLPage('seasons/LoadBalance.jsp?seasonId=1428400132&gbId=38&uname=&pword=')")

# %%
driver.execute_script("openEvent(0)") # Doesn't work. Need to switch to in-page Results frame to send this command
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# <ipython-input-30-62c1c78a4038> in <module>
# ----> 1 driver.execute_script("openEvent(0)")
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\envs\webscraping\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# JavascriptException: Message: ReferenceError: openEvent is not defined

# %%
'''
Using click-thru URL and parameters:

./seasons/EventMatches.jsp?TIM=1580219027557&twSessionId=hkftajyxbl&eventId=5179344132&teamId=777834135

Primary issue: getting 'could not determine which season' error pop-up, don't know how to pass along that info
- Sending Cookies?
'''

# FOR PSAL: Maspeth Mats


# Just first team for now
team_Ids = [777834135]

for Id in team_Ids:
    request_params = {
        'TIM': 1580219027557,
        'twSessionId': 'hkftajyxbl',
        'eventId': 5179344132,
        'teamId': Id}
        
    #job_descs = []
    #for i in range(NUM_PAGES):
        # Step 1, get the search page results
        #request_params.update({'start': i * 10})
    wrestling_response = requests.get(url=WRESTLING_URL + '/seasons' + '/EventMatches.jsp',
                                       params=request_params)
    
    if wrestling_response.status_code != 200:
            print('non-200 response for search page, skipping')
            continue
    
    wrestling_search_html = wrestling_response.text
    parsed_wrestling_searches = BeautifulSoup(wrestling_search_html, 'html.parser')
    
parsed_wrestling_searches

# %%
# All team_Id paramaters for in-page direct link URL (PSAL: Maspeth Mats)
#team_Ids = [1258447138, 194652138, 1258449138, 1258451138, 1258453138, 1258458138, 1258460138, 1258462138,
#            1258445138, 1258463138, 1258466138, 1258467138, 1258469138, 1258470138,1258473138,1258477138,
#            1258474138]

# %%
'''
Using in-page direct link URL and parameters:

./tw/seasons/LoadBalance.jsp?seasonId=1428400132&pageName=EventMatches.jsp&teamId=1258447138

Primary issue: this link results in redirect(?) to different URL and I don't know how to deal with that
'''
# FOR PSAL: Maspeth Mats

# Just first team for now
team_Ids = [1258447138]

for Id in team_Ids:
    request_params = {
        'seasonId': 1428400132,
        'pageName': 'EventMatches.jsp',
        'teamId': Id}
        
    #job_descs = []
    #for i in range(NUM_PAGES):
        # Step 1, get the search page results
        #request_params.update({'start': i * 10})
    wrestling_response = requests.get(url=WRESTLING_URL + '/tw' + '/seasons' + '/LoadBalance.jsp',
                                       params=request_params)
    
    if wrestling_response.status_code != 200:
            print('non-200 response for search page, skipping')
            continue
    
    wrestling_search_html = wrestling_response.text
    parsed_wrestling_searches = BeautifulSoup(wrestling_search_html, 'html.parser')
    
parsed_wrestling_searches
